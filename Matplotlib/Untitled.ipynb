# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
effectif = np.array([12, 20, 5, 2, 1])
xi = np.array([0, 1, 2, 3, 4])

# %%
print(np.array((xi, effectif)))
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.bar(xi, effectif, width = 0.005, color="black")
plt.xlabel("Nombre d'enfants")
plt.ylabel("Nombre de couples")
plt.subplot(1, 2, 2)
plt.xlabel("Nombre d'enfants")
#plt.ylabel("Nombre de couples")
plt.bar(xi, effectif, width= 0.01, color ="black")
plt.plot(xi, effectif, c='red', lw =1)
plt.show()
# Out:
# [[ 0  1  2  3  4]
#  [12 20  5  2  1]]

# %%
age = np.array([20, 30, 35, 40,45, 50, 55, 60, 65])
hi = np.array([0.0125, 0.025, 0.0208, 0.0292, 0.0417, 0.0292, 0.0125])

# %%
age = np.array([43,29,57,45,50,29,37,59,46,31,46,24,33,38,49,31,62,60,52,38,43,26,41,52,60,49,52,41,38,26,37,59,57,41,29,33,33,43,46,57,46,49,57,57,46,43])
bornes = [20,30,35,40,45,50,55,60,65]
plt.hist(age, bins= bornes,histtype= "stepfilled", color ='yellow', edgecolor = 'orange', density = True, linewidth = 13, alpha = 1)
plt.grid(True)
plt.show()

# %%
regions = ["Grand Lomé(GL)", "Maritime sans GL", "Plateaux", "Centrale", "Kara", "Savanes"]
pop = [2188376, 1346615, 1635946, 795529, 985512, 1143520]
plt.pie(pop, labels=regions, autopct='1%.1f%%' , startangle=90, explode=[0, 0.1, 0.3, 0.4, 0, 0.4], colors=['#ff9999', '#66b3ff', '#99ff99', '#55ff34', '#49ff99', 'yellow'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
