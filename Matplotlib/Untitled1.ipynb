# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
G1 = [7.2, 11.1, 11.4, 12.1, 13.3, 15.1, 15.7, 16.1, 18.5, 25.3]
G2  = [2.8, 3.3, 6.0, 7.7, 9.6, 9.8, 10.6, 10.8, 11.4, 15.6]
plt.subplot(1, 2, 1)
plt.boxplot(G1)
plt.subplot(1, 2, 2) 
plt.boxplot(G2)
#cart_G1 = np.array([11.4, 14.2, 16.1, 4.35, 23.15, 7.2, 11.4, 14.2, 16.1, 18.5])
#cart_G2 = np.array([6, 9.7, 10.8, -1.2, 18, 2.8, 6, ])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x76c225240cb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x76c225241100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x76c225240980>],
#  'medians': [<matplotlib.lines.Line2D at 0x76c2252415b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x76c225241850>],
#  'means': []}
