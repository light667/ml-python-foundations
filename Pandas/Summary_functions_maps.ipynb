# %%
import pandas as pd

# %%
dataset = pd.read_csv("/home/light667/Téléchargements/ml-python-foundations/Generative AI Tools - Platforms 2025.csv")
dataset
# Out:
#                  tool_name           company      category_canonical  \
# 0                  ChatGPT            OpenAI  LLMs & Chat Assistants
# 1                   Claude         Anthropic  LLMs & Chat Assistants
# 2                   Gemini            Google  LLMs & Chat Assistants
# 3               Midjourney        Midjourney     Image Gen & Editing
# 4         Stable Diffusion      Stability AI     Image Gen & Editing
# ..                     ...               ...                     ...
# 108             Silero VAD            Silero         Audio/Music/TTS
# 109  Papers with Code SOTA  Papers with Code            Search & RAG
# 110          Kaggle Models            Kaggle                   Other
# 111              OpenHands         OpenHands     Video Gen & Editing
# 112           LlamaGuard 2              Meta     Safety & Guardrails
#
#     modality_canonical  open_source  api_available   api_status  \
# 0           multimodal            0              1          api
# ...

# %%
dataset.tool_name.describe()
# Out:
# count         113
# unique        113
# top       ChatGPT
# freq            1
# Name: tool_name, dtype: object

# %%
dataset.open_source.describe()
# Out:
# count    113.000000
# mean       0.371681
# std        0.485406
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: open_source, dtype: float64

# %%
dataset.api_available.mean()
# Out:
# 0.9469026548672567

# %%
dataset.api_available.median()
# Out:
# 1.0

# %%
dataset.tool_name.unique()
# Out:
# array(['ChatGPT', 'Claude', 'Gemini', 'Midjourney', 'Stable Diffusion',
#        'DALL·E 3', 'Runway Gen-3', 'Pika', 'Suno', 'Udio', 'ElevenLabs',
#        'GitHub Copilot', 'Cursor', 'Sourcegraph Cody',
#        'Amazon Q Developer', 'JetBrains AI Assistant', 'Perplexity',
#        'Meta AI', 'Mistral Le Chat', 'Pinecone', 'Weaviate', 'Milvus',
#        'Qdrant', 'pgvector', 'LangChain', 'LlamaIndex', 'Haystack',
#        'Whisper', 'Deepgram', 'AssemblyAI', 'Google Speech-to-Text',
#        'NVIDIA NeMo Guardrails', 'Lakera Guard',
#        'Guardrails AI (framework)', 'LMQL', 'OpenRouter', 'Replicate',
#        'Modal', 'Vercel v0', 'Figma AI', 'Framer AI', 'Canva Magic Write',
#        'Notion AI', 'Cohere Command R', 'xAI Grok', 'DeepSeek R1',
#        'Mistral Large', 'Llama 3.1', 'Qwen 2.5', 'Gemma 2', 'DBRX',
#        'Phi-3', 'MPT-7B', 'Mixtral 8x7B', 'OpenAI o3-mini', 'GPT-4o',
#        'Claude 3.7 Sonnet', 'Grok-2', 'Mistral Codestral', 'Code Llama',
# ...

# %%
dataset.open_source.value_counts()
# Out:
# open_source
# 0    71
# 1    42
# Name: count, dtype: int64

# %%
dataset_release_year_mean = dataset.release_year.mean()
dataset.release_year.map(lambda p: p - dataset_release_year_mean)
# Out:
# 0     -0.20354
# 1      0.79646
# 2      0.79646
# 3     -0.20354
# 4     -0.20354
#         ...
# 108   -2.20354
# 109   -4.20354
# 110    0.79646
# 111    1.79646
# 112    0.79646
# Name: release_year, Length: 113, dtype: float64

# %%
def remean_release_year(row):
    row.release_year = row.release_year - dataset_release_year_mean
    return row
dataset.apply(remean_release_year, axis='columns')
# Out:
#                  tool_name           company      category_canonical  \
# 0                  ChatGPT            OpenAI  LLMs & Chat Assistants
# 1                   Claude         Anthropic  LLMs & Chat Assistants
# 2                   Gemini            Google  LLMs & Chat Assistants
# 3               Midjourney        Midjourney     Image Gen & Editing
# 4         Stable Diffusion      Stability AI     Image Gen & Editing
# ..                     ...               ...                     ...
# 108             Silero VAD            Silero         Audio/Music/TTS
# 109  Papers with Code SOTA  Papers with Code            Search & RAG
# 110          Kaggle Models            Kaggle                   Other
# 111              OpenHands         OpenHands     Video Gen & Editing
# 112           LlamaGuard 2              Meta     Safety & Guardrails
#
#     modality_canonical  open_source  api_available   api_status  \
# 0           multimodal            0              1          api
# ...

# %%
dataset.head(1)
# Out:
#   tool_name company      category_canonical modality_canonical  open_source  \
# 0   ChatGPT  OpenAI  LLMs & Chat Assistants         multimodal            0
#
#    api_available api_status              website source_domain  release_year  \
# 0              1        api  https://chatgpt.com   chatgpt.com          2022
#
#    ...  mod_image  mod_video  mod_audio  mod_code  mod_design  mod_infra  \
# 0  ...          0          0          0         0           0          0
#
#    mod_productivity  mod_safety  mod_multimodal  modality_count
# 0                 0           0               1               0
#
# [1 rows x 22 columns]
