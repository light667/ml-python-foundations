# %%
import pandas as pd

# %%
the_dataset = pd.read_csv("/home/light667/Téléchargements/ml-python-foundations/Generative AI Tools - Platforms 2025.csv")
the_dataset
# Out:
#                  tool_name           company      category_canonical  \
# 0                  ChatGPT            OpenAI  LLMs & Chat Assistants
# 1                   Claude         Anthropic  LLMs & Chat Assistants
# 2                   Gemini            Google  LLMs & Chat Assistants
# 3               Midjourney        Midjourney     Image Gen & Editing
# 4         Stable Diffusion      Stability AI     Image Gen & Editing
# ..                     ...               ...                     ...
# 108             Silero VAD            Silero         Audio/Music/TTS
# 109  Papers with Code SOTA  Papers with Code            Search & RAG
# 110          Kaggle Models            Kaggle                   Other
# 111              OpenHands         OpenHands     Video Gen & Editing
# 112           LlamaGuard 2              Meta     Safety & Guardrails
#
#     modality_canonical  open_source  api_available   api_status  \
# 0           multimodal            0              1          api
# ...

# %%
the_dataset.tool_name
# Out:
# 0                    ChatGPT
# 1                     Claude
# 2                     Gemini
# 3                 Midjourney
# 4           Stable Diffusion
#                ...
# 108               Silero VAD
# 109    Papers with Code SOTA
# 110            Kaggle Models
# 111                OpenHands
# 112             LlamaGuard 2
# Name: tool_name, Length: 113, dtype: object

# %%
the_dataset['tool_name']
# Out:
# 0                    ChatGPT
# 1                     Claude
# 2                     Gemini
# 3                 Midjourney
# 4           Stable Diffusion
#                ...
# 108               Silero VAD
# 109    Papers with Code SOTA
# 110            Kaggle Models
# 111                OpenHands
# 112             LlamaGuard 2
# Name: tool_name, Length: 113, dtype: object

# %%
the_dataset['tool_name'][100]
# Out:
# 'Google Vertex AI'

# %%
# indexing in pandas : pandas has its own accessor operators, loc and iloc
# index-based selection : iloc
the_dataset.iloc[7]
# Out:
# tool_name                             Pika
# company                               Pika
# category_canonical     Video Gen & Editing
# modality_canonical                   video
# open_source                              0
# api_available                            1
# api_status                             api
# website                   https://pika.art
# source_domain                     pika.art
# release_year                          2023
# years_since_release                      2
# mod_text                                 0
# mod_image                                0
# mod_video                                1
# mod_audio                                0
# mod_code                                 0
# mod_design                               0
# mod_infra                                0
# mod_productivity                         0
# mod_safety                               0
# mod_multimodal                           0
# modality_count                           1
# ...

# %%
the_dataset.iloc[:, 0]
# Out:
# 0                    ChatGPT
# 1                     Claude
# 2                     Gemini
# 3                 Midjourney
# 4           Stable Diffusion
#                ...
# 108               Silero VAD
# 109    Papers with Code SOTA
# 110            Kaggle Models
# 111                OpenHands
# 112             LlamaGuard 2
# Name: tool_name, Length: 113, dtype: object

# %%
the_dataset.iloc[:3, 1]
# Out:
# 0       OpenAI
# 1    Anthropic
# 2       Google
# Name: company, dtype: object

# %%
the_dataset.iloc[1:3, 0]
# Out:
# 1    Claude
# 2    Gemini
# Name: tool_name, dtype: object

# %%
the_dataset.iloc[[0, 1, 2], 0]
# Out:
# 0    ChatGPT
# 1     Claude
# 2     Gemini
# Name: tool_name, dtype: object

# %%
the_dataset.iloc[-5:]
# Out:
#                  tool_name           company   category_canonical  \
# 108             Silero VAD            Silero      Audio/Music/TTS
# 109  Papers with Code SOTA  Papers with Code         Search & RAG
# 110          Kaggle Models            Kaggle                Other
# 111              OpenHands         OpenHands  Video Gen & Editing
# 112           LlamaGuard 2              Meta  Safety & Guardrails
#
#     modality_canonical  open_source  api_available api_status  \
# 108              audio            1              1        api
# 109              infra            1              1        api
# 110              infra            1              1        api
# 111               code            1              1        api
# 112               text            1              1        api
#
#                                        website       source_domain  \
# 108     https://github.com/snakers4/silero-vad          github.com
# ...

# %%
# label-based selection
the_dataset.loc[1, 'tool_name']
# Out:
# 'Claude'

# %%
the_dataset.loc[:, ['tool_name','company', 'source_domain']]
# Out:
#                  tool_name           company       source_domain
# 0                  ChatGPT            OpenAI         chatgpt.com
# 1                   Claude         Anthropic           claude.ai
# 2                   Gemini            Google   gemini.google.com
# 3               Midjourney        Midjourney      midjourney.com
# 4         Stable Diffusion      Stability AI        stability.ai
# ..                     ...               ...                 ...
# 108             Silero VAD            Silero          github.com
# 109  Papers with Code SOTA  Papers with Code  paperswithcode.com
# 110          Kaggle Models            Kaggle          kaggle.com
# 111              OpenHands         OpenHands          github.com
# 112           LlamaGuard 2              Meta         ai.meta.com
#
# [113 rows x 3 columns]

# %% [markdown]
# #### manipulating the index
# the_dataset.set_index("tool_name")

# %%
the_dataset.iloc[:, 2]
# Out:
# 0      LLMs & Chat Assistants
# 1      LLMs & Chat Assistants
# 2      LLMs & Chat Assistants
# 3         Image Gen & Editing
# 4         Image Gen & Editing
#                 ...
# 108           Audio/Music/TTS
# 109              Search & RAG
# 110                     Other
# 111       Video Gen & Editing
# 112       Safety & Guardrails
# Name: category_canonical, Length: 113, dtype: object

# %%
the_dataset.loc[0:20, ['tool_name', 'company', 'category_canonical', 'release_year'] ]
# Out:
#                  tool_name              company      category_canonical  \
# 0                  ChatGPT               OpenAI  LLMs & Chat Assistants
# 1                   Claude            Anthropic  LLMs & Chat Assistants
# 2                   Gemini               Google  LLMs & Chat Assistants
# 3               Midjourney           Midjourney     Image Gen & Editing
# 4         Stable Diffusion         Stability AI     Image Gen & Editing
# 5                 DALL·E 3               OpenAI     Image Gen & Editing
# 6             Runway Gen-3               Runway     Video Gen & Editing
# 7                     Pika                 Pika     Video Gen & Editing
# 8                     Suno                 Suno     Video Gen & Editing
# 9                     Udio                 Udio     Video Gen & Editing
# 10              ElevenLabs           ElevenLabs         Audio/Music/TTS
# 11          GitHub Copilot               GitHub  LLMs & Chat Assistants
# ...

# %%
the_dataset.set_index("company")
# Out:
#                               tool_name      category_canonical  \
# company
# OpenAI                          ChatGPT  LLMs & Chat Assistants
# Anthropic                        Claude  LLMs & Chat Assistants
# Google                           Gemini  LLMs & Chat Assistants
# Midjourney                   Midjourney     Image Gen & Editing
# Stability AI           Stable Diffusion     Image Gen & Editing
# ...                                 ...                     ...
# Silero                       Silero VAD         Audio/Music/TTS
# Papers with Code  Papers with Code SOTA            Search & RAG
# Kaggle                    Kaggle Models                   Other
# OpenHands                     OpenHands     Video Gen & Editing
# Meta                       LlamaGuard 2     Safety & Guardrails
#
#                  modality_canonical  open_source  api_available   api_status  \
# company
# OpenAI                   multimodal            0              1          api
# ...

# %%
# conditional selection
the_dataset.category_canonical == 'LLMs & Chat Assistants'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# Name: category_canonical, Length: 113, dtype: bool

# %%
the_dataset.loc[the_dataset.category_canonical == 'LLMs & Chat Assistants']
# Out:
#                  tool_name              company      category_canonical  \
# 0                  ChatGPT               OpenAI  LLMs & Chat Assistants
# 1                   Claude            Anthropic  LLMs & Chat Assistants
# 2                   Gemini               Google  LLMs & Chat Assistants
# 11          GitHub Copilot               GitHub  LLMs & Chat Assistants
# 13        Sourcegraph Cody          Sourcegraph  LLMs & Chat Assistants
# 14      Amazon Q Developer  Amazon Web Services  LLMs & Chat Assistants
# 15  JetBrains AI Assistant            JetBrains  LLMs & Chat Assistants
# 17                 Meta AI                 Meta  LLMs & Chat Assistants
# 18         Mistral Le Chat           Mistral AI  LLMs & Chat Assistants
# 34                    LMQL              ETH SRI  LLMs & Chat Assistants
# 43        Cohere Command R               Cohere  LLMs & Chat Assistants
# 44                xAI Grok                  xAI  LLMs & Chat Assistants
# ...

# %%
the_dataset.loc[(the_dataset.category_canonical == 'LLMs & Chat Assistants') & (the_dataset.release_year <= 2023)]
# Out:
#                  tool_name              company      category_canonical  \
# 0                  ChatGPT               OpenAI  LLMs & Chat Assistants
# 1                   Claude            Anthropic  LLMs & Chat Assistants
# 2                   Gemini               Google  LLMs & Chat Assistants
# 11          GitHub Copilot               GitHub  LLMs & Chat Assistants
# 13        Sourcegraph Cody          Sourcegraph  LLMs & Chat Assistants
# 14      Amazon Q Developer  Amazon Web Services  LLMs & Chat Assistants
# 15  JetBrains AI Assistant            JetBrains  LLMs & Chat Assistants
# 34                    LMQL              ETH SRI  LLMs & Chat Assistants
# 44                xAI Grok                  xAI  LLMs & Chat Assistants
# 46           Mistral Large           Mistral AI  LLMs & Chat Assistants
# 47               Llama 3.1                 Meta  LLMs & Chat Assistants
# 52                  MPT-7B             MosaicML  LLMs & Chat Assistants
# ...

# %%
the_dataset.loc[(the_dataset.category_canonical == 'LLMs & Chat Assistants') | (the_dataset.release_year <= 2022)]
# Out:
#                  tool_name           company      category_canonical  \
# 0                  ChatGPT            OpenAI  LLMs & Chat Assistants
# 1                   Claude         Anthropic  LLMs & Chat Assistants
# 2                   Gemini            Google  LLMs & Chat Assistants
# 3               Midjourney        Midjourney     Image Gen & Editing
# 4         Stable Diffusion      Stability AI     Image Gen & Editing
# ..                     ...               ...                     ...
# 98   OpenAI Assistants API            OpenAI                   Other
# 100       Google Vertex AI      Google Cloud                   Other
# 107               WhisperX         Community    Speech-to-Text (ASR)
# 108             Silero VAD            Silero         Audio/Music/TTS
# 109  Papers with Code SOTA  Papers with Code            Search & RAG
#
#     modality_canonical  open_source  api_available   api_status  \
# 0           multimodal            0              1          api
# ...

# %%
# Pandas comes with a few built-in conditional selectors, two of which we will highlight here
# isin
the_dataset.loc[the_dataset.tool_name.isin(['ChatGPT', 'Leonardo AI', 'Perplexity', 'Monica'])]
# Out:
#       tool_name        company      category_canonical modality_canonical  \
# 0       ChatGPT         OpenAI  LLMs & Chat Assistants         multimodal
# 16   Perplexity  Perplexity AI                   Other         multimodal
# 71  Leonardo AI    Leonardo.Ai     Image Gen & Editing              image
#
#     open_source  api_available api_status                    website  \
# 0             0              1        api        https://chatgpt.com
# 16            0              1        api  https://www.perplexity.ai
# 71            0              1        api        https://leonardo.ai
#
#     source_domain  release_year  ...  mod_image  mod_video  mod_audio  \
# 0     chatgpt.com          2022  ...          0          0          0
# 16  perplexity.ai          2022  ...          0          0          0
# 71    leonardo.ai          2022  ...          1          0          0
#
#     mod_code  mod_design  mod_infra  mod_productivity  mod_safety  \
# ...

# %%
# isnull , notnull
the_dataset.loc[the_dataset.open_source.isnull()]
# Out:
# Empty DataFrame
# Columns: [tool_name, company, category_canonical, modality_canonical, open_source, api_available, api_status, website, source_domain, release_year, years_since_release, mod_text, mod_image, mod_video, mod_audio, mod_code, mod_design, mod_infra, mod_productivity, mod_safety, mod_multimodal, modality_count]
# Index: []
#
# [0 rows x 22 columns]

# %%
""" Assigning Data"""
# Out:
# ' Assigning Data'

# %%
the_dataset['author'] = 'light'
the_dataset['author']
# Out:
# 0      light
# 1      light
# 2      light
# 3      light
# 4      light
#        ...
# 108    light
# 109    light
# 110    light
# 111    light
# 112    light
# Name: author, Length: 113, dtype: object

# %%
the_dataset
# Out:
#                  tool_name           company      category_canonical  \
# 0                  ChatGPT            OpenAI  LLMs & Chat Assistants
# 1                   Claude         Anthropic  LLMs & Chat Assistants
# 2                   Gemini            Google  LLMs & Chat Assistants
# 3               Midjourney        Midjourney     Image Gen & Editing
# 4         Stable Diffusion      Stability AI     Image Gen & Editing
# ..                     ...               ...                     ...
# 108             Silero VAD            Silero         Audio/Music/TTS
# 109  Papers with Code SOTA  Papers with Code            Search & RAG
# 110          Kaggle Models            Kaggle                   Other
# 111              OpenHands         OpenHands     Video Gen & Editing
# 112           LlamaGuard 2              Meta     Safety & Guardrails
#
#     modality_canonical  open_source  api_available   api_status  \
# 0           multimodal            0              1          api
# ...

# %%
the_dataset['index_backwards'] = range(len(the_dataset), 0, -1)
the_dataset['index_backwards']
# Out:
# 0      113
# 1      112
# 2      111
# 3      110
# 4      109
#       ...
# 108      5
# 109      4
# 110      3
# 111      2
# 112      1
# Name: index_backwards, Length: 113, dtype: int64

# %%
the_dataset
# Out:
#                  tool_name           company      category_canonical  \
# 0                  ChatGPT            OpenAI  LLMs & Chat Assistants
# 1                   Claude         Anthropic  LLMs & Chat Assistants
# 2                   Gemini            Google  LLMs & Chat Assistants
# 3               Midjourney        Midjourney     Image Gen & Editing
# 4         Stable Diffusion      Stability AI     Image Gen & Editing
# ..                     ...               ...                     ...
# 108             Silero VAD            Silero         Audio/Music/TTS
# 109  Papers with Code SOTA  Papers with Code            Search & RAG
# 110          Kaggle Models            Kaggle                   Other
# 111              OpenHands         OpenHands     Video Gen & Editing
# 112           LlamaGuard 2              Meta     Safety & Guardrails
#
#     modality_canonical  open_source  api_available   api_status  \
# 0           multimodal            0              1          api
# ...
